# %% [markdown]
# # Projeto de Automação
#
# - passo 01: buscar dados das ações automaticamente
# - passo 02: realizar as análises solicitadas pelo gestor
# - passo 03: enviar automaticamente o email com a análise

# %%
# passo 1 - importação de biblioteca yahoo

# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\marce\anaconda3\lib\site-packages (0.2.20)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\marce\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\marce\anaconda3\lib\site-packages (from yfinance) (39.0.1)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\marce\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\marce\anaconda3\lib\site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: requests>=2.26 in c:\users\marce\anaconda3\lib\site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: html5lib>=1.1 in c:\users\marce\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\marce\anaconda3\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\marce\anaconda3\lib\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\marce\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\marce\anaconda3\lib\site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: pytz>=2022.5 in c:\users\marce\anaconda3\lib\site-packages (from yfinance) (2022.7)
# Requirement already satisfied: soupsieve>1.2 in c:\users\marce\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: cffi>=1.12 in c:\users\marce\anaconda3\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in c:\users\marce\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\marce\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\marce\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marce\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\marce\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marce\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\marce\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.14)
# Requirement already satisfied: pycparser in c:\users\marce\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)

# %%
import yfinance as yf


ticker = input("Digite o código da ação: ")
dados = yf.Ticker(ticker).history("6mo")
fechamento = dados.Close
fechamento.plot()
# Out:
# Digite o código da ação: PETR4.SA
# <Axes: xlabel='Date'>

# %%
# passo 02 -  realizar análises solicitadas pelo gestor
    # cotação máxima
    # cotação mínima
    # cotação atual
    
maxima = fechamento.max()
minimo = fechamento.min()

# %%
maxima
# Out:
# 30.100000381469727

# %%
minimo
# Out:
# 18.410430908203125

# %%
fechamento
# Out:
# Date
# 2022-12-15 00:00:00-03:00    18.410431
# 2022-12-16 00:00:00-03:00    18.418783
# 2022-12-19 00:00:00-03:00    18.694439
# 2022-12-20 00:00:00-03:00    19.270809
# 2022-12-21 00:00:00-03:00    19.688469
#                                ...
# 2023-06-09 00:00:00-03:00    28.418999
# 2023-06-12 00:00:00-03:00    28.916424
# 2023-06-13 00:00:00-03:00    28.860001
# 2023-06-14 00:00:00-03:00    30.100000
# 2023-06-15 00:00:00-03:00    29.590000
# Name: Close, Length: 124, dtype: float64

# %%
atual = fechamento[-1]

# %%
atual
# Out:
# 29.59000015258789

# %%
maxima = round(fechamento.max(),  2)
minimo = round(fechamento.min(), 2)
atual = round(fechamento[-1], 2)


print(maxima)
print(minimo)
print(atual)
# Out:
# 30.1
# 18.41
# 29.59

# %%
# !pip install pyautogui

import pyautogui
import time
import pyperclip

# %%
# passo 03: enviar automaticamente o email com a análise
    # abrir um nova aba (ctrl + t)
    # digitar endereço do site
    # clicar no botão escrever
    # digitar o destinatario (tab)
    # digitar assunto (tab)
    # preencher o corpo do email
    #clicar no botão enviar

# !pip install pyautogui - instalar se caso nao tiver instalado

# pyautogui.click -> clique com o mouse
# pyautogui.write -> escrever um texto
# pyautogui.press -> apertar uma tecla
# pyautogui.hotkey -> apertar uma combinação de teclas (ex: Ctrl + D)
# Passo a passo

pyautogui.PAUSE = 2

pyautogui.hotkey("ctrl", "t")
pyautogui.write("https://mail.google.com/mail/u/0/#inbox")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

time.sleep(5)

pyautogui.click(x=80, y=241)

pyautogui.write("marcelojonil09@gmail.com")
pyautogui.press("tab")
pyautogui.press("tab")
pyperclip.copy("Relatório de análise de mercado")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("tab")

texto = f"""
Prezados,

Segue o relatório de cotação das ações da Petrobras

Cotação máxima: R${maxima:,.2f}
Cotação mínima: R${minimo:,.2f}
Cotação atual: R${atual:,.2f}

Qualquer dúvida estou a disposição

Att

Marcelo Santana
"""
pyperclip.copy(texto)
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("ctrl", "enter")

# %%
time.sleep(5)
print(pyautogui.position())
